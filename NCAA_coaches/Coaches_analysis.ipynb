# %% [markdown]
# # Analysis of college coaching preformance

# %%
coach = read.csv('CollegeCoaches.csv')
coach = coach[,2:15]
str(coach)
# Out:
# 'data.frame':	3569 obs. of  14 variables:
#  $ Coach      : Factor w/ 3543 levels "A. V. Barrett",..: 3238 2610 2920 959 3141 2921 1549 812 493 1142 ...
#  $ From       : int  1987 1917 1992 1918 1978 1990 1916 1983 1912 1945 ...
#  $ To         : int  2000 1917 1999 1919 1979 1991 1925 1985 1913 1949 ...
#  $ Last.School: Factor w/ 439 levels "Abilene Christian",..: 312 269 415 402 204 363 383 285 14 119 ...
#  $ Yrs        : int  7 1 8 2 2 2 7 3 2 5 ...
#  $ G          : int  191 12 235 26 56 55 87 81 16 113 ...
#  $ W          : int  70 5 151 14 25 12 46 47 11 54 ...
#  $ L          : int  121 7 84 12 31 43 41 34 5 59 ...
#  $ W.L.       : num  0.366 0.417 0.643 0.538 0.446 0.218 0.529 0.58 0.688 0.478 ...
#  $ CREG       : int  0 0 3 0 0 0 0 1 0 0 ...
#  $ CTRN       : int  0 0 2 0 0 0 0 1 0 0 ...
#  $ NCAA       : int  0 NA 2 NA 0 0 NA 1 NA 0 ...
#  $ FF         : int  0 NA 0 NA 0 0 NA 0 NA 0 ...
#  $ NC         : int  0 NA 0 NA 0 0 NA 0 NA 0 ...

# %%
library(corrplot)
corr_set = coach[complete.cases(coach),]
corr_set = corr_set[,5:14]
corrplot(cor(corr_set,method = 'spearman'), method = 'number')
# Out:
# Plot with title ""
